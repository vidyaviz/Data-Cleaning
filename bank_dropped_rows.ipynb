# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
bank1 = pd.read_csv("/Users/Vidya/Downloads/Bank_1.csv", sep = ';', header = 0, names = ["Age","Job","Marital Status","Education","Default","Housing","Loan","Contact","Month","Day of week","Duration","Campaign","pdays","Previous","PreviousOutcome","EmpVarRate","ConsPriceIndx","ConsConfIndx","euribor3m","nr.employed","y"])

# %%
type(bank1)
# Out:
# pandas.core.frame.DataFrame

# %%
#pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)
pd.options.display.float_format = '{:.2f}'.format

# %%
bank1.dtypes
# Out:
# Age                float64
# Job                 object
# Marital Status      object
# Education           object
# Default             object
# Housing             object
# Loan                object
# Contact             object
# Month               object
# Day of week         object
# Duration           float64
# Campaign           float64
# pdays               object
# Previous            object
# PreviousOutcome     object
# EmpVarRate          object
# ConsPriceIndx      float64
# ConsConfIndx       float64
# euribor3m           object
# nr.employed         object
# y                   object
# dtype: object

# %%
bank1.isnull().any()
# Out:
# Age                 True
# Job                False
# Marital Status     False
# Education          False
# Default            False
# Housing            False
# Loan               False
# Contact            False
# Month              False
# Day of week        False
# Duration           False
# Campaign           False
# pdays              False
# Previous           False
# PreviousOutcome    False
# EmpVarRate         False
# ConsPriceIndx       True
# ConsConfIndx        True
# euribor3m           True
# nr.employed         True
# y                   True
# dtype: bool

# %%
bank1.isnull().sum()
# Out:
# Age                3
# Job                0
# Marital Status     0
# Education          0
# Default            0
# Housing            0
# Loan               0
# Contact            0
# Month              0
# Day of week        0
# Duration           0
# Campaign           0
# pdays              0
# Previous           0
# PreviousOutcome    0
# EmpVarRate         0
# ConsPriceIndx      4
# ConsConfIndx       1
# euribor3m          3
# nr.employed        4
# y                  4
# dtype: int64

# %%
bank_d.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-08fa866d3cbb> in <module>()
# ----> 1 bank_d.isnull().sum()
#
# NameError: name 'bank_d' is not defined

# %%
#bank_d.isnull().any()

# %%
bank1
# Out:
#        Age            Job Marital Status            Education  Default  \
# 0     30.0    blue-collar        married             basic.9y       no
# 1     39.0       services         single          high.school       no
# 2     25.0       services        married          high.school       no
# 3     38.0       services        married             basic.9y       no
# 4     47.0         admin.        married    university.degree       no
# 5     32.0       services         single    university.degree       no
# 6     32.0         admin.         single    university.degree       no
# 7     41.0   entrepreneur        married    university.degree  unknown
# 8     31.0       services       divorced  professional.course       no
# 9     35.0    blue-collar        married             basic.9y  unknown
# 10    25.0       services         single             basic.6y  unknown
# 11    36.0  self-employed         single             basic.4y       no
# ...

# %%
bank_d = bank1.drop(bank1.index[[574,569,650,678]])

# %%
bank_d
# Out:
#        Age            Job Marital Status            Education  Default  \
# 0    30.00    blue-collar        married             basic.9y       no
# 1    39.00       services         single          high.school       no
# 2    25.00       services        married          high.school       no
# 3    38.00       services        married             basic.9y       no
# 4    47.00         admin.        married    university.degree       no
# 5    32.00       services         single    university.degree       no
# 6    32.00         admin.         single    university.degree       no
# 7    41.00   entrepreneur        married    university.degree  unknown
# 8    31.00       services       divorced  professional.course       no
# 9    35.00    blue-collar        married             basic.9y  unknown
# 10   25.00       services         single             basic.6y  unknown
# 11   36.00  self-employed         single             basic.4y       no
# ...

# %%
bank1['Marital Status'].value_counts()
# Out:
# married                  2509
# single                   1153
# divorced                  445
# unknown                    11
# divorceded”;”basic.9y       1
# Name: Marital Status, dtype: int64

# %%
#locate rows with issues
bank1.loc[(bank1['Marital Status']=='divorceded”;”basic.9y')]
# Out:
#       Age          Job         Marital Status Education Default Housing  \
# 650  41.0  blue-collar  divorceded”;”basic.9y        no     yes      no
#
#          Loan Contact Month Day of week ...   Campaign  pdays     Previous  \
# 650  cellular     may   thu         102 ...      999.0      0  nonexistent
#
#     PreviousOutcome EmpVarRate ConsPriceIndx  ConsConfIndx  euribor3m  \
# 650            -1.8     92.893         -46.2         1.327     5099.1
#
#     nr.employed    y
# 650          no  NaN
#
# [1 rows x 21 columns]

# %%
bank1['Job'].value_counts()
# Out:
# admin.           1012
# blue-collar       884
# technician        691
# services          393
# management        324
# retired           166
# self-employed     159
# entrepreneur      148
# unemployed        111
# housemaid         110
# student            82
# unknown            39
# Name: Job, dtype: int64

# %%
bank_d['Education'].value_counts(dropna = False)
# Out:
# university.degree      1263
# high.school             921
# basic.9y                573
# professional.course     535
# basic.4y                429
# basic.6y                226
# unknown                 167
# illiterate                1
# Name: Education, dtype: int64

# %%
#locate rows with issues

bank1.loc[(bank1['Education']=='basic.6yes”;”no')]
# Out:
#       Age          Job Marital Status        Education     Default   Housing  \
# 574  47.0  blue-collar        married  basic.6yes”;”no  yess”;”yes  cellular
#
#     Loan Contact Month Day of week ...   Campaign        pdays Previous  \
# 574  jul     mon   298           3 ...        0.0  nonexistent      1.4
#
#     PreviousOutcome EmpVarRate ConsPriceIndx  ConsConfIndx  euribor3m  \
# 574          93.918      -42.7         4.962        5228.1         no
#
#     nr.employed    y
# 574         NaN  NaN
#
# [1 rows x 21 columns]

# %%
bank1['Default'].value_counts()
# Out:
# no            3312
# unknown        803
# yes              2
# yess”;”yes       1
# noo”;”yes        1
# Name: Default, dtype: int64

# %%
#locate rows with issues

bank1.loc[(bank1['Default']== 'yess”;”yes') ]
# Out:
#       Age          Job Marital Status        Education     Default   Housing  \
# 574  47.0  blue-collar        married  basic.6yes”;”no  yess”;”yes  cellular
#
#     Loan Contact Month Day of week ...   Campaign        pdays Previous  \
# 574  jul     mon   298           3 ...        0.0  nonexistent      1.4
#
#     PreviousOutcome EmpVarRate ConsPriceIndx  ConsConfIndx  euribor3m  \
# 574          93.918      -42.7         4.962        5228.1         no
#
#     nr.employed    y
# 574         NaN  NaN
#
# [1 rows x 21 columns]

# %%
bank1.loc[(bank1['Default']== 'noo”;”yes') ]
# Out:
#       Age     Job Marital Status          Education    Default Housing  \
# 569  33.0  admin.         single  university.degree  noo”;”yes     yes
#
#          Loan Contact Month Day of week ...   Campaign  pdays     Previous  \
# 569  cellular     aug   tue         275 ...      999.0      0  nonexistent
#
#     PreviousOutcome EmpVarRate ConsPriceIndx  ConsConfIndx  euribor3m  \
# 569             1.4     93.444         -36.1         4.963     5228.1
#
#     nr.employed    y
# 569          no  NaN
#
# [1 rows x 21 columns]

# %%
bank1['Housing'].value_counts()
# Out:
# yes         2173
# no          1840
# unknown      105
# cellular       1
# Name: Housing, dtype: int64

# %%
bank_d['Housing'].value_counts()
# Out:
# yes        2172
# no         1838
# unknown     105
# Name: Housing, dtype: int64

# %%
bank1.loc[(bank1['Housing']== 'cellular') ]
# Out:
#       Age          Job Marital Status        Education     Default   Housing  \
# 574  47.0  blue-collar        married  basic.6yes”;”no  yess”;”yes  cellular
#
#     Loan Contact Month Day of week ...   Campaign        pdays Previous  \
# 574  jul     mon   298           3 ...        0.0  nonexistent      1.4
#
#     PreviousOutcome EmpVarRate ConsPriceIndx  ConsConfIndx  euribor3m  \
# 574          93.918      -42.7         4.962        5228.1         no
#
#     nr.employed    y
# 574         NaN  NaN
#
# [1 rows x 21 columns]

# %%
bank1['Loan'].value_counts()
# Out:
# no          3348
# yes          663
# unknown      105
# cellular       2
# jul            1
# Name: Loan, dtype: int64

# %%
bank_d['Loan'].value_counts()
# Out:
# no         3347
# yes         663
# unknown     105
# Name: Loan, dtype: int64

# %%
bank1['Contact'].value_counts()
# Out:
# cellular     2649
# telephone    1467
# may             1
# mon             1
# aug             1
# Name: Contact, dtype: int64

# %%
bank_d['Contact'].value_counts()
# Out:
# cellular     2649
# telephone    1466
# Name: Contact, dtype: int64

# %%
bank1['Month'].value_counts()
# Out:
# may    1377
# jul     710
# aug     635
# jun     530
# nov     446
# apr     215
# oct      69
# sep      64
# mar      48
# dec      22
# thu       1
# tue       1
# 298       1
# Name: Month, dtype: int64

# %%
bank_d['Month'].value_counts()
# Out:
# may    1376
# jul     710
# aug     635
# jun     530
# nov     446
# apr     215
# oct      69
# sep      64
# mar      48
# dec      22
# Name: Month, dtype: int64

# %%
bank1['Day of week'].value_counts()
# Out:
# thu                            858
# mon                            854
# tue                            840
# wed                            795
# fri                            768
# 102                              1
# 3                                1
# 275                              1
# thu”;-;1;999;0;nonexistent"      1
# Name: Day of week, dtype: int64

# %%
bank_d['Day of week'].value_counts()
# Out:
# thu    858
# mon    854
# tue    840
# wed    795
# fri    768
# Name: Day of week, dtype: int64

# %%
bank1['Duration'].value_counts()
# Out:
# 77.0      24
# 112.0     23
# 73.0      22
# 81.0      21
# 122.0     20
# 145.0     20
# 113.0     20
# 90.0      20
# 83.0      20
# 88.0      19
# 131.0     19
# 114.0     19
# 135.0     19
# 87.0      18
# 159.0     18
# 107.0     18
# 155.0     18
# 103.0     18
# 130.0     17
# 147.0     17
# 111.0     17
# 139.0     17
# 160.0     17
# 161.0     17
# 204.0     17
# 69.0      17
# 180.0     17
# 95.0      17
# 181.0     16
# 136.0     16
#           ..
# 522.0      1
# 726.0      1
# 687.0      1
# 857.0      1
# 992.0      1
# 1311.0     1
# 823.0      1
# 1009.0     1
# 1806.0     1
# 757.0      1
# 1207.0     1
# 1300.0     1
# 892.0      1
# 646.0      1
# 716.0      1
# 1720.0     1
# 1128.0     1
# 1186.0     1
# 449.0      1
# 1190.0     1
# 611.0      1
# 825.0      1
# 898.0      1
# 638.0      1
# 373.0      1
# 457.0      1
# 1365.0     1
# 637.0      1
# 1590.0     1
# 371.0      1
# Name: Duration, Length: 830, dtype: int64

# %%
bank_d['Duration'].value_counts()
# Out:
# 77.0      24
# 112.0     23
# 73.0      22
# 81.0      21
# 90.0      20
# 145.0     20
# 83.0      20
# 122.0     20
# 113.0     20
# 114.0     19
# 88.0      19
# 131.0     19
# 135.0     19
# 159.0     18
# 103.0     18
# 87.0      18
# 107.0     18
# 155.0     18
# 69.0      17
# 139.0     17
# 95.0      17
# 161.0     17
# 204.0     17
# 147.0     17
# 111.0     17
# 180.0     17
# 130.0     17
# 160.0     17
# 181.0     16
# 164.0     16
#           ..
# 726.0      1
# 687.0      1
# 515.0      1
# 771.0      1
# 800.0      1
# 1009.0     1
# 1186.0     1
# 1806.0     1
# 757.0      1
# 1207.0     1
# 1300.0     1
# 892.0      1
# 646.0      1
# 716.0      1
# 1720.0     1
# 1128.0     1
# 823.0      1
# 1190.0     1
# 992.0      1
# 611.0      1
# 825.0      1
# 898.0      1
# 638.0      1
# 373.0      1
# 371.0      1
# 1365.0     1
# 637.0      1
# 1590.0     1
# 449.0      1
# 457.0      1
# Name: Duration, Length: 828, dtype: int64

# %%
bank1['Campaign'].value_counts()
# Out:
# 1.000      1762
# 2.000      1039
# 3.000       548
# 4.000       291
# 5.000       142
# 6.000        98
# 7.000        60
# 8.000        36
# 9.000        32
# 10.000       20
# 11.000       19
# 12.000       16
# 17.000       14
# 13.000       11
# 16.000        7
# 14.000        6
# 29.000        2
# 23.000        2
# 19.000        2
# 22.000        2
# 15.000        2
# 999.000       2
# 18.000        1
# 93.994        1
# 27.000        1
# 24.000        1
# 35.000        1
# 0.000         1
# Name: Campaign, dtype: int64

# %%
bank_d['Campaign'].value_counts()
# Out:
# 1.0     1762
# 2.0     1039
# 3.0      548
# 4.0      291
# 5.0      142
# 6.0       98
# 7.0       60
# 8.0       36
# 9.0       32
# 10.0      20
# 11.0      19
# 12.0      16
# 17.0      14
# 13.0      11
# 16.0       7
# 14.0       6
# 29.0       2
# 15.0       2
# 22.0       2
# 19.0       2
# 23.0       2
# 18.0       1
# 24.0       1
# 27.0       1
# 35.0       1
# Name: Campaign, dtype: int64

# %%
bank1['pdays'].value_counts()
# Out:
# 999            3955
# 3                52
# 6                42
# 4                14
# 7                10
# 10                8
# 12                5
# 5                 4
# 0                 4
# 2                 4
# 9                 3
# 1                 3
# 13                2
# 15                2
# 16                2
# 18                2
# 11                1
# 14                1
# nonexistent       1
# 17                1
# -36.4             1
# 19                1
# 21                1
# Name: pdays, dtype: int64

# %%
bank_d['pdays'].value_counts()
# Out:
# 999    3955
# 3        52
# 6        42
# 4        14
# 7        10
# 10        8
# 12        5
# 2         4
# 5         4
# 9         3
# 1         3
# 0         2
# 13        2
# 15        2
# 16        2
# 18        2
# 11        1
# 14        1
# 17        1
# 19        1
# 21        1
# Name: pdays, dtype: int64

# %%
bank1['Previous'].value_counts()
# Out:
# 0              3519
# 1               475
# 2                78
# 3                25
# 4                14
# 5                 2
# 6                 2
# nonexistent       2
# 4.855             1
# 1.4               1
# Name: Previous, dtype: int64

# %%
bank_d['Previous'].value_counts()
# Out:
# 0    3519
# 1     475
# 2      78
# 3      25
# 4      14
# 5       2
# 6       2
# Name: Previous, dtype: int64

# %%
bank1['PreviousOutcome'].value_counts()
# Out:
# nonexistent    3519
# failure         454
# success         142
# 5191              1
# 1.4               1
# -1.8              1
# 93.918            1
# Name: PreviousOutcome, dtype: int64

# %%
bank_d['PreviousOutcome'].value_counts()
# Out:
# nonexistent    3519
# failure         454
# success         142
# Name: PreviousOutcome, dtype: int64

# %%
bank1['EmpVarRate'].value_counts()
# Out:
# 1.4       1624
# -1.8       882
# 1.1        757
# -0.1       392
# -2.9       164
# -3.4       104
# -1.7        87
# -1.1        83
# -3          21
# -0.2         1
# 92.893       1
# no           1
# -42.7        1
# 93.444       1
# Name: EmpVarRate, dtype: int64

# %%
bank_d['EmpVarRate'].value_counts()
# Out:
# 1.4     1624
# -1.8     882
# 1.1      757
# -0.1     392
# -2.9     164
# -3.4     104
# -1.7      87
# -1.1      83
# -3        21
# -0.2       1
# Name: EmpVarRate, dtype: int64

# %%
bank1['ConsPriceIndx'].value_counts()
# Out:
#  93.994    755
#  93.918    665
#  92.893    596
#  93.444    527
#  94.465    431
#  93.200    386
#  93.075    201
#  92.201     75
#  92.963     75
#  92.431     43
#  94.199     39
#  92.649     36
#  94.027     33
#  94.215     30
#  92.379     25
#  92.843     25
#  94.767     24
#  94.055     24
#  93.876     23
#  93.369     23
#  92.713     21
#  94.601     20
#  93.749     14
#  92.469     14
#  93.798      6
# -46.200      1
# -36.100      1
#  4.962       1
#  92.756      1
# Name: ConsPriceIndx, dtype: int64

# %%
bank_d['ConsPriceIndx'].value_counts()
# Out:
# 93.994    755
# 93.918    665
# 92.893    596
# 93.444    527
# 94.465    431
# 93.200    386
# 93.075    201
# 92.201     75
# 92.963     75
# 92.431     43
# 94.199     39
# 92.649     36
# 94.027     33
# 94.215     30
# 92.379     25
# 92.843     25
# 94.767     24
# 94.055     24
# 93.876     23
# 93.369     23
# 92.713     21
# 94.601     20
# 93.749     14
# 92.469     14
# 93.798      6
# 92.756      1
# Name: ConsPriceIndx, dtype: int64

# %%
bank1['ConsConfIndx'].value_counts()
# Out:
# -36.400      757
# -42.700      666
# -46.200      596
# -36.100      527
# -41.800      431
# -42.000      386
# -47.100      201
# -31.400       75
# -40.800       75
# -26.900       43
# -37.500       39
# -30.100       36
# -38.300       33
# -40.300       30
# -29.800       25
# -50.000       25
# -50.800       24
# -39.800       24
# -34.800       23
# -40.000       23
# -33.000       21
# -49.500       20
# -34.600       14
# -33.600       14
# -40.400        6
#  5228.100      1
#  1.327         1
#  4.963         1
# -45.900        1
# Name: ConsConfIndx, dtype: int64

# %%
bank_d['ConsConfIndx'].value_counts(dropna = False)
# Out:
# -36.4    757
# -42.7    666
# -46.2    596
# -36.1    527
# -41.8    431
# -42.0    386
# -47.1    201
# -31.4     75
# -40.8     75
# -26.9     43
# -37.5     39
# -30.1     36
# -38.3     33
# -40.3     30
# -50.0     25
# -29.8     25
# -50.8     24
# -39.8     24
# -34.8     23
# -40.0     23
# -33.0     21
# -49.5     20
# -33.6     14
# -34.6     14
# -40.4      6
# -45.9      1
# Name: ConsConfIndx, dtype: int64

# %%
bank1['euribor3m'].value_counts(dropna = False)
# Out:
# 4.857     274
# 4.963     255
# 4.962     236
# 4.961     212
# 4.856     138
# 4.965     114
# 4.964     110
# 1.405     106
# 4.96      105
# 4.968     101
# 4.076     100
# 4.864      97
# 4.12       82
# 4.855      81
# 4.86       80
# 4.959      76
# 4.859      76
# 4.191      73
# 4.966      72
# 1.266      71
# 1.281      68
# 4.858      66
# 4.958      66
# 4.153      64
# 4.967      62
# 4.021      61
# 1.299      59
# 1.334      58
# 1.327      58
# 1.25       54
#          ...
# 4.343       1
# 1.059       1
# 1.028       1
# 0.921       1
# 1.224       1
# 1.4         1
# 0.889       1
# 1.531       1
# 5.045       1
# 0.829       1
# 0.778       1
# 1.046       1
# 1.538       1
# 0.768       1
# 5228.1      1
# 3.329       1
# 0.724       1
# 0.937       1
# 0.709       1
# 0.707       1
# 0.782       1
# 1.044       1
# 1.032       1
# 1.031       1
# 4.592       1
# 4.921       1
# 0.721       1
# 1.043       1
# 1.52        1
# 0.885       1
# ...

# %%
bank_d['euribor3m'].value_counts()
# Out:
# 4.857    274
# 4.963    255
# 4.962    236
# 4.961    212
# 4.856    138
# 4.965    114
# 4.964    110
# 1.405    106
# 4.96     105
# 4.968    101
# 4.076    100
# 4.864     97
# 4.12      82
# 4.855     81
# 4.86      80
# 4.859     76
# 4.959     76
# 4.191     73
# 4.966     72
# 1.266     71
# 1.281     68
# 4.858     66
# 4.958     66
# 4.153     64
# 4.967     62
# 4.021     61
# 1.299     59
# 1.334     58
# 1.327     58
# 1.25      54
#         ...
# 1.028      1
# 0.829      1
# 0.885      1
# 0.921      1
# 1.224      1
# 1.4        1
# 0.889      1
# 1.531      1
# 5.045      1
# 0.987      1
# 1.215      1
# 0.996      1
# 1.032      1
# 3.329      1
# 0.709      1
# 0.724      1
# 0.752      1
# 0.937      1
# 1.538      1
# 0.782      1
# 1.031      1
# 0.778      1
# 4.592      1
# 4.921      1
# 0.721      1
# 1.043      1
# 1.044      1
# 1.52       1
# 1.046      1
# 1.65       1
# Name: euribor3m, Length: 234, dtype: int64

# %%
bank1['nr.employed'].value_counts(dropna = False)
# Out:
# 5228.1    1624
# 5099.1     821
# 5191       757
# 5195.8     392
# 5076.2     164
# 5017.5     104
# 4991.6      87
# 4963.6      83
# 5008.7      59
# 5023.5      21
# NaN          4
# no           2
# 5176.3       1
# Name: nr.employed, dtype: int64

# %%
bank_d['nr.employed'].value_counts(dropna = False)
# Out:
# 5228.1    1624
# 5099.1     821
# 5191       757
# 5195.8     392
# 5076.2     164
# 5017.5     104
# 4991.6      87
# 4963.6      83
# 5008.7      59
# 5023.5      21
# NaN          2
# 5176.3       1
# Name: nr.employed, dtype: int64

# %%
bank1['y'].value_counts()
# Out:
# no     3664
# yes     451
# Name: y, dtype: int64

# %%
bank_d['y'].value_counts(dropna = False)
# Out:
# no     3664
# yes     451
# Name: y, dtype: int64

# %%
bank_d.dtypes
# Out:
# Age                float64
# Job                 object
# Marital Status      object
# Education           object
# Default             object
# Housing             object
# Loan                object
# Contact             object
# Month               object
# Day of week         object
# Duration           float64
# Campaign           float64
# pdays               object
# Previous            object
# PreviousOutcome     object
# EmpVarRate          object
# ConsPriceIndx      float64
# ConsConfIndx       float64
# euribor3m           object
# nr.employed         object
# y                   object
# dtype: object

# %%
bank_d.isnull().sum()
# Out:
# Age                3
# Job                0
# Marital Status     0
# Education          0
# Default            0
# Housing            0
# Loan               0
# Contact            0
# Month              0
# Day of week        0
# Duration           0
# Campaign           0
# pdays              0
# Previous           0
# PreviousOutcome    0
# EmpVarRate         0
# ConsPriceIndx      3
# ConsConfIndx       0
# euribor3m          2
# nr.employed        2
# y                  0
# dtype: int64

# %%
## replace nan in Age with col mean value and change datatype
bank_d['Age'].fillna(bank_d['Age']. mean (axis = 0), inplace = True)

# %%
bank_d['Age'] = bank_d['Age'].astype('int64')

# %%
bank_d['Duration'] = bank_d['Duration'].astype('int64')

# %%
bank_d['Campaign'] = bank_d['Campaign'].astype('int64')

# %%
bank_d['pdays'] = bank_d['pdays'].astype('int64')

# %%
bank_d['Previous'].fillna(bank_d['Previous']. mean(axis = 0), inplace = True)

# %%
bank_d['Previous'] = bank_d['Previous'].astype('int64')

# %%
bank_d['EmpVarRate'] = bank_d['EmpVarRate'].astype('float64')

# %%
bank_d['EmpVarRate'].astype('float64')
# Out:
# 0      -1.80
# 1       1.10
# 2       1.40
# 3       1.40
# 4      -0.10
# 5      -1.10
# 6      -1.10
# 7      -0.10
# 8      -0.10
# 9       1.10
# 10      1.40
# 11      1.40
# 12      1.10
# 13      1.40
# 14     -1.80
# 15      1.40
# 16      1.40
# 17      1.40
# 18      1.40
# 19      1.40
# 20      1.40
# 21     -1.80
# 22      1.40
# 23      1.40
# 24      1.10
# 25      1.40
# 26      1.10
# 27     -1.80
# 28      1.10
# 29      1.40
#         ...
# 4089   -3.40
# 4090    1.10
# 4091    1.10
# 4092    1.40
# 4093    1.40
# 4094   -3.40
# 4095    1.40
# 4096    1.10
# 4097    1.40
# 4098    1.40
# 4099    1.40
# 4100   -1.80
# 4101    1.40
# 4102    1.40
# 4103    1.10
# 4104    1.40
# 4105    1.40
# 4106   -1.80
# 4107    1.40
# 4108   -1.80
# 4109   -3.40
# 4110    1.10
# 4111   -1.70
# 4112   -0.10
# 4113   -0.10
# 4114    1.40
# 4115    1.40
# 4116   -1.80
# 4117    1.40
# 4118   -0.10
# Name: EmpVarRate, Length: 4115, dtype: float64

# %%
bank1['EmpVarRate'].dtypes
# Out:
# dtype('O')

# %%
bank_d['ConsPriceIndx'].fillna(bank_d['ConsPriceIndx']. mean (axis = 0), inplace = True)

# %%
bank_d['ConsConfIndx'].fillna(bank_d['ConsConfIndx']. mean (axis = 0), inplace = True)

# %%
bank_d['euribor3m'] = bank_d['euribor3m'].astype('float64')

# %%
bank_d['euribor3m'].fillna(bank_d['euribor3m']. mean (axis = 0), inplace = True)

# %%
bank1['euribor3m'].value_counts()
# Out:
# 4.857     274
# 4.963     255
# 4.962     236
# 4.961     212
# 4.856     138
# 4.965     114
# 4.964     110
# 1.405     106
# 4.96      105
# 4.968     101
# 4.076     100
# 4.864      97
# 4.12       82
# 4.855      81
# 4.86       80
# 4.859      76
# 4.959      76
# 4.191      73
# 4.966      72
# 1.266      71
# 1.281      68
# 4.858      66
# 4.958      66
# 4.153      64
# 4.967      62
# 4.021      61
# 1.299      59
# 1.327      58
# 1.334      58
# 1.25       54
#          ...
# 1.059       1
# 1.028       1
# 0.921       1
# 0.885       1
# 1.224       1
# 0.889       1
# 1.4         1
# 1.531       1
# 0.937       1
# 0.987       1
# 0.829       1
# 0.778       1
# 0.782       1
# 5228.1      1
# 3.329       1
# 0.724       1
# 0.752       1
# 5.045       1
# 0.707       1
# 1.538       1
# 1.032       1
# 1.046       1
# 1.031       1
# 4.592       1
# 4.921       1
# 0.721       1
# 1.043       1
# 1.52        1
# 1.044       1
# 0.672       1
# ...

# %%
bank_d.isnull().sum()
# Out:
# Age                0
# Job                0
# Marital Status     0
# Education          0
# Default            0
# Housing            0
# Loan               0
# Contact            0
# Month              0
# Day of week        0
# Duration           0
# Campaign           0
# pdays              0
# Previous           0
# PreviousOutcome    0
# EmpVarRate         0
# ConsPriceIndx      0
# ConsConfIndx       0
# euribor3m          0
# nr.employed        2
# y                  0
# dtype: int64

# %%
bank_d['nr.employed'] = bank_d['nr.employed'].astype('float64')

# %%
bank_d['nr.employed'].fillna(bank_d['nr.employed']. mean(axis = 0), inplace = True)

# %%
bank_d['nr.employed'].value_counts()
# Out:
# 5228.100000    1624
# 5099.100000     821
# 5191.000000     757
# 5195.800000     392
# 5076.200000     164
# 5017.500000     104
# 4991.600000      87
# 4963.600000      83
# 5008.700000      59
# 5023.500000      21
# 5166.516898       2
# 5176.300000       1
# Name: nr.employed, dtype: int64

# %%
bank_d['nr.employed'].dtypes
# Out:
# dtype('float64')

# %%
bank_d['y'].value_counts()
# Out:
# no     3664
# yes     451
# Name: y, dtype: int64

# %%
bank1['y'] = bank1['y'].astype('bool')

# %%
bank_d.dtypes
# Out:
# Age                  int64
# Job                 object
# Marital Status      object
# Education           object
# Default             object
# Housing             object
# Loan                object
# Contact             object
# Month               object
# Day of week         object
# Duration             int64
# Campaign             int64
# pdays                int64
# Previous             int64
# PreviousOutcome     object
# EmpVarRate         float64
# ConsPriceIndx      float64
# ConsConfIndx       float64
# euribor3m          float64
# nr.employed        float64
# y                   object
# dtype: object

# %%
#sanity checks of values
bank_d.describe(include = 'all')
# Out:
#                 Age     Job Marital Status          Education Default Housing  \
# count   4115.000000    4115           4115               4115    4115    4115
# unique          NaN      12              4                  8       3       3
# top             NaN  admin.        married  university.degree      no     yes
# freq            NaN    1011           2507               1263    3311    2172
# mean      40.188578     NaN            NaN                NaN     NaN     NaN
# std       10.940104     NaN            NaN                NaN     NaN     NaN
# min       18.000000     NaN            NaN                NaN     NaN     NaN
# 25%       32.000000     NaN            NaN                NaN     NaN     NaN
# 50%       38.000000     NaN            NaN                NaN     NaN     NaN
# 75%       47.000000     NaN            NaN                NaN     NaN     NaN
# max      250.000000     NaN            NaN                NaN     NaN     NaN
#
# ...

# %%
bank_d.loc[(bank_d['Age'] >=120) | (bank_d['Age'] < 18) ]
# Out:
#      Age         Job Marital Status Education Default Housing Loan   Contact  \
# 385  143  unemployed        married  basic.4y      no      no   no  cellular
# 394  250      admin.        married  basic.9y      no      no   no  cellular
#
#     Month Day of week ...  Campaign  pdays  Previous  PreviousOutcome  \
# 385   may         wed ...         2    999         0      nonexistent
# 394   aug         thu ...         1    999         0      nonexistent
#
#     EmpVarRate  ConsPriceIndx  ConsConfIndx  euribor3m  nr.employed   y
# 385       -1.8         92.893         -46.2      1.334       5099.1  no
# 394        1.4         93.444         -36.1      4.968       5228.1  no
#
# [2 rows x 21 columns]

# %%
mask_age=(bank_d['Age'] >=120)

# %%
bank_d['Age'].loc[mask_age] = None
# Out:
# /Users/Vidya/anaconda2/lib/python2.7/site-packages/pandas/core/indexing.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
bank_d['Age'].describe()
# Out:
# count    4113.000000
# mean       40.112570
# std        10.318056
# min        18.000000
# 25%        32.000000
# 50%        38.000000
# 75%        47.000000
# max        88.000000
# Name: Age, dtype: float64

# %%
bank_d['Age'].fillna(bank_d['Age'].mean(axis = 0), inplace = True)

# %%
bank_d.groupby(['Age']).mean()
# Out:
#        Duration  Campaign  pdays  Previous  EmpVarRate  ConsPriceIndx  \
# Age
# 18.00    288.33      1.00 336.33      1.00       -2.30          93.43
# 19.00    338.00      4.00 999.00      0.00       -1.80          92.89
# 20.00    195.25      2.00 999.00      0.75       -2.02          93.30
# 21.00    342.00      2.00 999.00      0.14       -1.84          93.28
# 22.00    208.10      2.30 899.40      0.40        0.23          93.69
# 23.00    272.31      2.50 999.00      0.31       -0.14          93.66
# 24.00    249.07      2.39 946.82      0.32       -0.35          93.52
# 25.00    235.74      2.91 964.30      0.19       -0.12          93.69
# 26.00    265.42      2.32 918.79      0.31       -0.38          93.60
# 27.00    233.69      2.32 941.77      0.20       -0.10          93.60
# 28.00    273.19      2.33 971.37      0.17       -0.32          93.54
# 29.00    240.26      2.85 956.09      0.14       -0.01          93.46
# ...

# %%
#data exploration

# %%
bank_d['Age'].plot(kind = 'density', figsize=(10, 8)),
plt.xlabel('Age of clients'),
plt.title('Distribution of the age of clients'),
plt.xlim(0,120),
# Out:
# ((0, 120),)

# %%
# Job
bank_d['Job'].value_counts().plot(kind='bar',figsize=(10, 8)),
plt.xlabel('Job'),
plt.title('Jobs held by clients'),
# Out:
# (Text(0.5,1,u'Jobs held by clients'),)

# %%
bank_d['Marital Status'].value_counts().plot(kind='bar',figsize=(10, 8)),
plt.xlabel('Marital status of clients'),
plt.title('Marital status of clients'),
# Out:
# (Text(0.5,1,u'Marital status of clients'),)

# %%
bank_d['Education'].value_counts().plot(kind='bar',figsize=(10, 8)),
plt.xlabel('Education'),
plt.title('Levels of education of clients')
# Out:
# (Text(0.5,1,u'Levels of education of clients'),)

# %%
#pie chart for default
bank_d['Default'].value_counts().plot(kind='pie',autopct='%.2f', figsize =(10,8))

# %%
#Contact
bank_d['Contact'].value_counts().plot(kind='pie',autopct='%.2f', figsize =(10,8))

# %%
bank_d['Month'].value_counts().plot(kind='bar',figsize=(10, 8)),
plt.xlabel('Month'),
plt.title('Month on which the clients were last contacted')
# Out:
# Text(0.5,1,u'Month on which the clients')

# %%
bank_d['Day of week'].value_counts().plot(kind='bar',figsize=(10, 8)),
plt.xlabel('Day'),
plt.title('Day on which the clients were last contacted')
# Out:
# Text(0.5,1,u'Day on which the clients were last contacted')

# %%
#plot pie-chart: Housing loan percentages
bank_d['Housing'].value_counts().plot(kind='pie',autopct='%.2f', figsize =(10,8))

# %%
bank_d['Duration'].max()
# Out:
# 3643

# %%
#density plot for call duration
bank_d['Duration'].plot(kind='density', figsize = (10,8)),
plt.xlabel('Last Contact Duration in seconds'),
plt.title('Campaign Call Duration'),
plt.xlim(0,4000)
# Out:
# (0, 4000)

# %%
bank_d['Campaign'].plot(kind = 'hist',bins =40, figsize=(10, 8)),
plt.xlabel('Number of contacts made'),
plt.title('Histogram of the number times clients were contacted'),
plt.xlim(0,40)
plt
# Out:
# <module 'matplotlib.pyplot' from '/Users/Vidya/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.pyc'>

# %%
mask_pdays = bank_d['pdays'] != 999

# %%
bank_d.loc[mask_pdays,'pdays'].plot(kind = 'hist',bins =30, figsize=(10, 8)),
plt.xlabel('Number of contacts made'),
plt.title('Number of days since the last contact with clients'),
plt.xlim(1,40)
# Out:
# (1, 40)

# %%
bank_d['Previous'].value_counts().plot(kind = 'bar', figsize=(10, 8)),
plt.xlabel('Number of times the clients were contacted'),
plt.title('Contacts made with the clients for previous campaigns'),

# %%
bank_d['PreviousOutcome'].value_counts().plot(kind='pie',autopct='%.2f', figsize =(10,8))

# %%
pd.unique(bank_d['ConsConfIndx'])
# Out:
# array([-46.2, -36.4, -41.8, -42. , -37.5, -42.7, -36.1, -34.8, -50. ,
#        -40.8, -49.5, -38.3, -29.8, -26.9, -34.6, -47.1, -39.8, -33.6,
#        -50.8, -31.4, -30.1, -40.3, -40. , -40.4, -33. , -45.9])

# %% [markdown]
# pdays               object
# Previous            object
# PreviousOutcome     object
# EmpVarRate          object
# ConsPriceIndx      float64
# ConsConfIndx       float64
# euribor3m           object
# nr.employed         object
# y

# %%
# duration and y

# %%
bank_d.boxplot(column ='Duration', by = 'y', figsize = (10,8))

# %%
#Age and consconfindx

# %%
bank_d.boxplot(column ='Age', by = 'ConsConfIndx', figsize = (15,10))

# %%
#Job and Duration

# %%
bank_d.boxplot(column ='Duration', by = 'Job', figsize = (15,10))

# %%
#scatter matrix

from pandas.tools.plotting import scatter_matrix

# %%
scatter_matrix(bank_d, alpha= 0.2, figsize = (25,25),diagonal = 'hist')
# Out:
# /Users/Vidya/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:1: FutureWarning: 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.
#   """Entry point for launching an IPython kernel.
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a20eddc90>,
# ...
#       dtype=object)
