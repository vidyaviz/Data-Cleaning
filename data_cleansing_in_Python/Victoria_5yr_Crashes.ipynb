# %%
import pandas as pd

# %%
crashes= pd.read_csv("/Users/Vidya/Downloads/Crashes_Last_Five_Years.csv",dayfirst=True, parse_dates=True)

# %%
print(crashes.shape)
print(crashes.describe())

# %%
crashes.head(3)
# Out:
#             X          Y  OBJECTID   ACCIDENT_NO                 ABS_CODE  \
# 0  145.003865 -37.894103   3402744  T20130015887  ABS to receive accident
# 1  145.360983 -37.755923   3402745  T20130015889  ABS to receive accident
# 2  144.973222 -37.807724   3402746  T20130015892  ABS to receive accident
#
#   ACCIDENT_STATUS ACCIDENT_DATE ACCIDENT_TIME ALCOHOLTIME  \
# 0        Finished      1/8/2013      16.15.00          No
# 1        Finished      1/8/2013      17.50.00          No
# 2        Finished      1/8/2013      18.14.00         Yes
#
#             ACCIDENT_TYPE      ...       DEG_URBAN_ALL       LGA_NAME_ALL  \
# 0  Collision with vehicle      ...          MELB_URBAN  GLEN EIRA,BAYSIDE
# 1  Collision with vehicle      ...          MELB_URBAN       YARRA RANGES
# 2  Collision with vehicle      ...          MELB_URBAN    YARRA,MELBOURNE
#
#                   REGION_NAME_ALL SRNS SRNS_ALL               RMA  \
# ...

# %%
crashes['FATALITY'].sum()
# Out:
# 1416

# %%
crashes_new['FATALITY'].sum()
# Out:
# 1405

# %% [markdown]
# print(crashes['LGA_NAME_ALL'].str.title())
#
# print(crashes['LGA_NAME'].str.title())
#
# crashes['REGION_NAME_ALL'].str.title()

# %%
list(crashes)
# Out:
# ['X',
#  'Y',
#  'OBJECTID',
#  'ACCIDENT_NO',
#  'ABS_CODE',
#  'ACCIDENT_STATUS',
#  'ACCIDENT_DATE',
#  'ACCIDENT_TIME',
#  'ALCOHOLTIME',
#  'ACCIDENT_TYPE',
#  'DAY_OF_WEEK',
#  'DCA_CODE',
#  'HIT_RUN_FLAG',
#  'LIGHT_CONDITION',
#  'POLICE_ATTEND',
#  'ROAD_GEOMETRY',
#  'SEVERITY',
#  'SPEED_ZONE',
#  'RUN_OFFROAD',
#  'NODE_ID',
#  'LONGITUDE',
#  'LATITUDE',
#  'NODE_TYPE',
#  'LGA_NAME',
#  'REGION_NAME',
#  'VICGRID_X',
#  'VICGRID_Y',
#  'TOTAL_PERSONS',
#  'INJ_OR_FATAL',
#  'FATALITY',
#  'SERIOUSINJURY',
#  'OTHERINJURY',
#  'NONINJURED',
#  'MALES',
#  'FEMALES',
#  'BICYCLIST',
#  'PASSENGER',
#  'DRIVER',
#  'PEDESTRIAN',
#  'PILLION',
#  'MOTORIST',
#  'UNKNOWN',
#  'PED_CYCLIST_5_12',
#  'PED_CYCLIST_13_18',
#  'OLD_PEDESTRIAN',
#  'OLD_DRIVER',
#  'YOUNG_DRIVER',
#  'ALCOHOL_RELATED',
#  'UNLICENCSED',
#  'NO_OF_VEHICLES',
#  'HEAVYVEHICLE',
#  'PASSENGERVEHICLE',
#  'MOTORCYCLE',
#  'PUBLICVEHICLE',
#  'DEG_URBAN_NAME',
#  'DEG_URBAN_ALL',
#  'LGA_NAME_ALL',
# ...

# %% [markdown]
# #### Count number of observations

# %%
#crashes['ACCIDENT_NO'].nunique()
#crashes['DCA_CODE'].nunique()
#crashes['ROAD_GEOMETRY'].nunique()
#crashes['LGA_NAME'].nunique()
crashes['DEG_URBAN_ALL'].nunique()
#crashes['REGION_NAME'].nunique()
#crashes['REGION_NAME_ALL'].nunique()
#crashes['ROAD_GEOMETRY'].nunique()

#list(crashes['REGION_NAME'])
# Out:
# 16

# %%
crashes_new = crashes[[
 'ACCIDENT_NO',
 'ACCIDENT_DATE',
 'ACCIDENT_TIME',
 'ACCIDENT_TYPE',
 'DAY_OF_WEEK',
 'DCA_CODE',
 'HIT_RUN_FLAG',
 'LIGHT_CONDITION',
 'ROAD_GEOMETRY',
 'SEVERITY',
 'SPEED_ZONE',
 'RUN_OFFROAD',
 'LONGITUDE',
 'LATITUDE',
 'LGA_NAME',
 'REGION_NAME',
 'TOTAL_PERSONS',
 'INJ_OR_FATAL',
 'FATALITY',
 'SERIOUSINJURY',
 'OTHERINJURY',
 'NONINJURED',
 'MALES',
 'FEMALES',
 'BICYCLIST',
 'PASSENGER',
 'DRIVER',
 'PEDESTRIAN',
 'PILLION',
 'MOTORIST',
 'UNKNOWN',
 'PED_CYCLIST_5_12',
 'PED_CYCLIST_13_18',
 'OLD_PEDESTRIAN',
 'OLD_DRIVER',
 'YOUNG_DRIVER',
 'ALCOHOL_RELATED',
 'UNLICENCSED',
 'NO_OF_VEHICLES',
 'HEAVYVEHICLE',
 'PASSENGERVEHICLE',
 'MOTORCYCLE',
 'PUBLICVEHICLE',
 'DEG_URBAN_NAME',
 'DEG_URBAN_ALL',
 'RMA',
 'RMA_ALL',
 'DIVIDED',
 'DIVIDED_ALL',
 'STAT_DIV_NAME']].copy()

# %%
crashes_new.shape
# Out:
# (74908, 50)

# %%
crashes_new.head()
# Out:
#     ACCIDENT_NO ACCIDENT_DATE ACCIDENT_TIME                  ACCIDENT_TYPE  \
# 0  T20130015887      1/8/2013      16.15.00         Collision with vehicle
# 1  T20130015889      1/8/2013      17.50.00         Collision with vehicle
# 2  T20130015892      1/8/2013      18.14.00         Collision with vehicle
# 3  T20130015893      1/8/2013      18.15.00         Collision with vehicle
# 4  T20130015894      1/8/2013      16.30.00  Collision with a fixed object
#
#   DAY_OF_WEEK                                          DCA_CODE HIT_RUN_FLAG  \
# 0    Thursday                   REAR END(VEHICLES IN SAME LANE)           No
# 1    Thursday                   REAR END(VEHICLES IN SAME LANE)           No
# 2    Thursday   VEHICLE OFF FOOTPATH STRIKES VEH ON CARRIAGEWAY           No
# 3    Thursday                                     RIGHT THROUGH           No
# 4    Thursday  RIGHT OFF CARRIAGEWAY INTO OBJECT/PARKED VEHICLE           No
#
# ...

# %% [markdown]
# #### Check for nulls

# %%
crashes.isnull().sum()
# Out:
# X                        0
# Y                        0
# OBJECTID                 0
# ACCIDENT_NO              0
# ABS_CODE                 0
# ACCIDENT_STATUS          0
# ACCIDENT_DATE            0
# ACCIDENT_TIME            0
# ALCOHOLTIME              0
# ACCIDENT_TYPE            0
# DAY_OF_WEEK           1476
# DCA_CODE                 0
# HIT_RUN_FLAG             0
# LIGHT_CONDITION          0
# POLICE_ATTEND            0
# ROAD_GEOMETRY            0
# SEVERITY                 0
# SPEED_ZONE               0
# RUN_OFFROAD              0
# NODE_ID                  0
# LONGITUDE                0
# LATITUDE                 0
# NODE_TYPE               22
# LGA_NAME                 0
# REGION_NAME              0
# VICGRID_X                0
# VICGRID_Y                0
# TOTAL_PERSONS            0
# INJ_OR_FATAL             0
# FATALITY                 0
#                      ...
# BICYCLIST                0
# PASSENGER                0
# DRIVER                   0
# ...

# %% [markdown]
# #### Rows with null

# %%
crash_nans = crashes_new[crashes_new.isnull().any(axis=1)]
len(crash_nans)
# Out:
# 2946

# %% [markdown]
# #### Combine date and time field

# %%
crashes_new["DateTime"] = crashes_new["ACCIDENT_DATE"].map(str) + " " + crashes_new["ACCIDENT_TIME"]

# %%
crashes_new.head(2)
# Out:
#     ACCIDENT_NO ACCIDENT_DATE ACCIDENT_TIME           ACCIDENT_TYPE  \
# 0  T20130015887      1/8/2013      16.15.00  Collision with vehicle
# 1  T20130015889      1/8/2013      17.50.00  Collision with vehicle
#
#   DAY_OF_WEEK                         DCA_CODE HIT_RUN_FLAG  \
# 0    Thursday  REAR END(VEHICLES IN SAME LANE)           No
# 1    Thursday  REAR END(VEHICLES IN SAME LANE)           No
#
#          LIGHT_CONDITION        ROAD_GEOMETRY               SEVERITY  \
# 0                    Day       T intersection  Other injury accident
# 1  Dark Street lights on  Not at intersection  Other injury accident
#
#          ...         MOTORCYCLE PUBLICVEHICLE  DEG_URBAN_NAME  DEG_URBAN_ALL  \
# 0        ...                  0             0      MELB_URBAN     MELB_URBAN
# 1        ...                  0             0      MELB_URBAN     MELB_URBAN
#
#                 RMA                      RMA_ALL  DIVIDED  DIVIDED_ALL  \
# ...

# %% [markdown]
# #### Drop rows with null

# %%
crashes_new = crashes_new.dropna(axis=0, how = 'any')
len(crashes_new)
# Out:
# 71962

# %%
crashes_new.to_excel('/Users/Vidya/Projects/datasets/crashes_clean.xlsx',index = False)
